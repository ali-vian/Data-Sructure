# %%
import pandas as pd
data = pd.read_csv('dataAcak1.csv',delimiter=";")
listData = data.values.tolist()
print(listData)
# Out:
# [[220411100002, 'Himawan Rajata', '93,33'], [220411100003, 'Samiah Novitasari', '87,4'], [220411100004, 'Yance Hasanah', '64,33'], [220411100005, 'Bala Thamrin', '95,59'], [220411100006, 'Kenari Mahfud Suwarno', '98,64'], [220411100007, 'Yuliana Vanesa Fujiati', '79,77'], [220411100008, 'Gading Permadi', '80,33'], [220411100009, 'Erik Megantara', '89,36'], [220411100010, 'Gasti Citra Mayasari', '53,55'], [220411100011, 'Putri Mulyani', '61,43'], [220411100012, 'Nadia Kezia Susanti', '99,41'], [220411100013, 'Aris Gamani Hidayat', '83,23'], [220411100014, 'Dartono Napitupulu', '60,24'], [220411100015, 'Sari Novitasari', '88,50'], [220411100016, 'Hairyanto Gading Simanjuntak', '78,85'], [220411100017, 'Baktianto Budiyanto', '64,59'], [220411100018, 'Gawati Laksmiwati', '88,12'], [220411100019, 'Dagel Wijaya', '66,36'], [220411100020, 'Wirda Wahyuni', '53,31'], [220411100021, 'Ophelia Utami', '70,56'], [220411100022, 'Oskar Prayoga', '58,51'], [220411100023, 'Gilda Ophelia Rahmawati', '94,20'], [220411100024, 'Olga Utama', '58,8'], [220411100025, 'Zaenab Puspita', '79,43'], [220411100026, 'Zaenab Nasyiah', '91,41'], [220411100027, 'Septi Puspa Handayani', '50,42'], [220411100028, 'Hesti Eva Nuraini', '60,86'], [220411100029, 'Amelia Kamaria Nuraini', '98,26'], [220411100030, 'Dacin Saputra', '84,29'], [220411100031, 'Siti Nadia Pertiwi', '72,7'], [220411100032, 'Najwa Puspita', '79,34'], [220411100033, 'Garan Mandala', '85,26'], [220411100034, 'Gina Puspita', '64,85'], [220411100035, 'Puput Laksita', '69,52'], [220411100036, 'Hana Yulia Astuti', '82,52'], [220411100037, 'Rahmi Lailasari', '72,90'], [220411100038, 'Patricia Winarsih', '88,49'], [220411100039, 'Zelaya Maryati', '83,8'], [220411100040, 'Leo Putra', '80,30'], [220411100041, 'Jamal Sitorus', '77,43'], [220411100042, 'Nurul Maryati', '75,77'], [220411100043, 'Nadine Uyainah', '67,47'], [220411100044, 'Maryanto Samosir', '53,51'], [220411100045, 'Edi Praba Manullang', '97,28'], [220411100046, 'Kemba Sirait', '51,8'], [220411100047, 'Ade Jatmiko Tarihoran', '59,32'], [220411100048, 'Asmadi Tampubolon', '65,73'], [220411100049, 'Belinda Nurdiyanti', '80,29'], [220411100050, 'Sadina Vanya Mandasari', '72,25'], [220411100051, 'Dacin Erik Nababan', '97,4'], [220411100052, 'Humaira Karen Andriani', '74,7'], [220411100053, 'Farhunnisa Betania Lailasari', '64,83'], [220411100054, 'Upik Dongoran', '94,30'], [220411100055, 'Zamira Wahyuni', '96,89'], [220411100056, 'Pardi Ganda Budiman', '68,58'], [220411100057, 'Hasta Gantar Natsir', '76,76'], [220411100058, 'Parman Martana Prasetyo', '97,23'], [220411100059, 'Margana Prakasa', '54,82'], [220411100060, 'Diah Sudiati', '62,54'], [220411100061, 'Nabila Halimah', '84,57'], [220411100062, 'Utama Siregar', '53,10'], [220411100063, 'Ana Zelda Usamah', '60,88'], [220411100064, 'Darimin Mustofa Jailani', '50,17'], [220411100065, 'Umi Yulianti', '90,27'], [220411100066, 'Dalima Nasyidah', '54,26'], [220411100067, 'Titi Usamah', '99,0'], [220411100068, 'Betania Yuliana Purnawati', '53,30'], [220411100069, 'Jono Wijaya', '61,50'], [220411100070, 'Yessi Zulaika', '54,38'], [220411100071, 'Tirtayasa Sitorus', '67,67'], [220411100072, 'Nasim Firgantoro', '67,81'], [220411100073, 'Vanya Lintang Anggraini', '87,10'], [220411100074, 'Dian Samiah Mardhiyah', '88,61'], [220411100075, 'Limar Kuswoyo', '66,29'], [220411100076, 'Makuta Sihombing', '58,18'], [220411100077, 'Prayoga Hardiansyah', '97,82'], [220411100078, 'Salman Saefullah', '95,40'], [220411100079, 'Anastasia Septi Safitri', '89,63'], [220411100080, 'Tania Ratna Yuniar', '79,58'], [220411100081, 'Lukman Makara Nashiruddin', '92,72'], [220411100082, 'Gasti Yulianti', '90,66'], [220411100083, 'Maria Riyanti', '75,62'], [220411100084, 'Nadine Ophelia Utami', '88,77'], [220411100085, 'Dodo Hakim', '96,68'], [220411100086, 'Prayoga Budiman', '69,28'], [220411100087, 'Taswir Gamblang Dabukke', '77,41'], [220411100088, 'Ade Padmi Laksita', '80,90'], [220411100089, 'Lintang Jessica Hariyah', ' ...

# %%
def dispData(data):
    print(f"NPM\t\tNAMA\t\t\t\tNILAI")
    for i in data :
        print(f"{i[0]}\t{i[1]}"+(" "*(32-len(i[1])))+i[2])
dispData(listData)
# Out:
# NPM		NAMA				NILAI
# 220411100002	Himawan Rajata                  93,33
# 220411100003	Samiah Novitasari               87,4
# 220411100004	Yance Hasanah                   64,33
# 220411100005	Bala Thamrin                    95,59
# 220411100006	Kenari Mahfud Suwarno           98,64
# 220411100007	Yuliana Vanesa Fujiati          79,77
# 220411100008	Gading Permadi                  80,33
# 220411100009	Erik Megantara                  89,36
# 220411100010	Gasti Citra Mayasari            53,55
# 220411100011	Putri Mulyani                   61,43
# 220411100012	Nadia Kezia Susanti             99,41
# 220411100013	Aris Gamani Hidayat             83,23
# 220411100014	Dartono Napitupulu              60,24
# 220411100015	Sari Novitasari                 88,50
# 220411100016	Hairyanto Gading Simanjuntak    78,85
# 220411100017	Baktianto Budiyanto             64,59
# 220411100018	Gawati Laksmiwati               88,12
# 220411100019	Dagel Wijaya                    66,36
# 220411100020	Wirda Wahyuni                   53,31
# 220411100021	Ophelia Utami                   70,56
# 220411100022	Oskar Prayoga                   58,51
# 220411100023	Gilda Ophelia Rahmawati         94,20
# 220411100024	Olga Utama                      58,8
# 220411100025	Zaenab Puspita                  79,43
# 220411100026	Zaenab Nasyiah                  91,41
# 220411100027	Septi Puspa Handayani           50,42
# 220411100028	Hesti Eva Nuraini               60,86
# 220411100029	Amelia Kamaria Nuraini          98,26
# 220411100030	Dacin Saputra                   84,29
# 220411100031	Siti Nadia Pertiwi              72,7
# 220411100032	Najwa Puspita                   79,34
# 220411100033	Garan Mandala                   85,26
# 220411100034	Gina Puspita                    64,85
# 220411100035	Puput Laksita                   69,52
# 220411100036	Hana Yulia Astuti               82,52
# 220411100037	Rahmi Lailasari                 72,90
# 220411100038	Patricia Winarsih               88,49
# 220411100039	Zelaya Maryati                  83,8
# 220411100040	Leo Putra                       80,30
# 220411100041	Jamal Sitorus                   77,43
# 220411100042	Nurul Maryati                   75,77
# 220411100043	Nadine Uyainah                  67,47
# 220411100044	Maryanto Samosir                53,51
# 220411100045	Edi Praba Manullang             97,28
# 220411100046	Kemba Sirait                    51,8
# 220411100047	Ade Jatmiko Tarihoran           59,32
# 220411100048	Asmadi Tampubolon               65,73
# 220411100049	Belinda Nurdiyanti              80,29
# 220411100050	Sadina Vanya Mandasari          72,25
# 220411100051	Dacin Erik Nababan              97,4
# 220411100052	Humaira Karen Andriani          74,7
# 220411100053	Farhunnisa Betania Lailasari    64,83
# 220411100054	Upik Dongoran                   94,30
# 220411100055	Zamira Wahyuni                  96,89
# 220411100056	Pardi Ganda Budiman             68,58
# 220411100057	Hasta Gantar Natsir             76,76
# 220411100058	Parman Martana Prasetyo         97,23
# 220411100059	Margana Prakasa                 54,82
# 220411100060	Diah Sudiati                    62,54
# 220411100061	Nabila Halimah                  84,57
# 220411100062	Utama Siregar                   53,10
# 220411100063	Ana Zelda Usamah                60,88
# 220411100064	Darimin Mustofa Jailani         50,17
# 220411100065	Umi Yulianti                    90,27
# 220411100066	Dalima Nasyidah                 54,26
# 220411100067	Titi Usamah                     99,0
# 220411100068	Betania Yuliana Purnawati       53,30
# 220411100069	Jono Wijaya                     61,50
# 220411100070	Yessi Zulaika                   54,38
# 220411100071	Tirtayasa Sitorus               67,67
# 220411100072	Nasim Firgantoro                67,81
# 220411100073	Vanya Lintang Anggraini         87,10
# 220411100074	Dian Samiah Mardhiyah           88,61
# 220411100075	Limar Kuswoyo                   66,29
# 220411100076	Makuta Sihombing                58,18
# 220411100077	Prayoga Hardiansyah             97,82
# 220411100078	Salman Saefullah                95,40
# 220411100079	Anastasia Septi Safitri         89,63
# 220411100080	Tania Ratna Yuniar              79,58
# 220411100081	Lukman Makara Nashiruddin       92,72
# 220411100082	Gasti Yulianti                  90,66
# 220411100083	Maria Riyanti                   75,62
# 220411100084	Nadine Ophelia Utami            88,77
# 220411100085	Dodo Hakim                      96,68
# 220411100086	Prayoga Budiman                 69,28
# 220411100087	Taswir Gamblang Dabukke         77,41
# 220411100088	Ade Padmi Laksita               80,90
# 220411100089	Lintang Jessica Hariyah         99,28
# 220411100090	Zelda Rahimah                   60,52
# 220411100091	Mulyanto Zulkarnain             97,37
# 220411100092	Daru Widodo                     86,59
# 220411100093	Capa Prabowo                    86,11
# 220411100094	Rini Yuliana Laksita            100,26
# 220411100095	Uli Uli Rahimah                 56,45
# 220411100096	Wulan Nasyiah                   99,27
# 220411100097	Zulfa Elma Padmasari            93,81
# 220411100098	Ani Maida Aryani                80,64
# 220411100099	Darimin Kambali Anggriawan      50,45
# 220411100100	Dewi Melinda Kuswandari         91,27
# 220411100101	Jasmin Pudjiastuti              68,43

# %%
def selectionSort(a):
    for i in range(len(a)-1):
        idx=i
        for j in range(i+1,len(a)):
            if int(a[idx][2]) > int(a[j][2]):
                idx=j
        a[idx],a[i]=a[i],a[idx]
    return a

# %%
y = listData.copy()
x = selectionSort(y)
dispData(x)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [21], in <cell line: 2>()
#       1 y = listData.copy()
# ----> 2 x = selectionSort(y)
#       3 dispData(x)
#
# Input In [20], in selectionSort(a)
#       3 idx=i
#       4 for j in range(i+1,len(a)):
# ----> 5     if int(a[idx][2]) > int(a[j][2]):
#       6         idx=j
#       7 a[idx],a[i]=a[i],a[idx]
#
# ValueError: invalid literal for int() with base 10: '93,33'

# %%
# assending dari kiri ke kanan
def bubbleSort(data):
    for i in range(len(data)-1,0,-1):
        for j in range(i):
            if data[j][2] >data[j+1][2]:
                data[j],data[j+1]=data[j+1],data[j]
    return data

# %%
z = listData.copy()
dispData(bubbleSort(z))
# Out:
# NPM		NAMA				NILAI
# 220411100094	Rini Yuliana Laksita            100,26
# 220411100064	Darimin Mustofa Jailani         50,17
# 220411100027	Septi Puspa Handayani           50,42
# 220411100099	Darimin Kambali Anggriawan      50,45
# 220411100046	Kemba Sirait                    51,8
# 220411100062	Utama Siregar                   53,10
# 220411100068	Betania Yuliana Purnawati       53,30
# 220411100020	Wirda Wahyuni                   53,31
# 220411100044	Maryanto Samosir                53,51
# 220411100010	Gasti Citra Mayasari            53,55
# 220411100066	Dalima Nasyidah                 54,26
# 220411100070	Yessi Zulaika                   54,38
# 220411100059	Margana Prakasa                 54,82
# 220411100095	Uli Uli Rahimah                 56,45
# 220411100076	Makuta Sihombing                58,18
# 220411100022	Oskar Prayoga                   58,51
# 220411100024	Olga Utama                      58,8
# 220411100047	Ade Jatmiko Tarihoran           59,32
# 220411100014	Dartono Napitupulu              60,24
# 220411100090	Zelda Rahimah                   60,52
# 220411100028	Hesti Eva Nuraini               60,86
# 220411100063	Ana Zelda Usamah                60,88
# 220411100011	Putri Mulyani                   61,43
# 220411100069	Jono Wijaya                     61,50
# 220411100060	Diah Sudiati                    62,54
# 220411100004	Yance Hasanah                   64,33
# 220411100017	Baktianto Budiyanto             64,59
# 220411100053	Farhunnisa Betania Lailasari    64,83
# 220411100034	Gina Puspita                    64,85
# 220411100048	Asmadi Tampubolon               65,73
# 220411100075	Limar Kuswoyo                   66,29
# 220411100019	Dagel Wijaya                    66,36
# 220411100043	Nadine Uyainah                  67,47
# 220411100071	Tirtayasa Sitorus               67,67
# 220411100072	Nasim Firgantoro                67,81
# 220411100101	Jasmin Pudjiastuti              68,43
# 220411100056	Pardi Ganda Budiman             68,58
# 220411100086	Prayoga Budiman                 69,28
# 220411100035	Puput Laksita                   69,52
# 220411100021	Ophelia Utami                   70,56
# 220411100050	Sadina Vanya Mandasari          72,25
# 220411100031	Siti Nadia Pertiwi              72,7
# 220411100037	Rahmi Lailasari                 72,90
# 220411100052	Humaira Karen Andriani          74,7
# 220411100083	Maria Riyanti                   75,62
# 220411100042	Nurul Maryati                   75,77
# 220411100057	Hasta Gantar Natsir             76,76
# 220411100087	Taswir Gamblang Dabukke         77,41
# 220411100041	Jamal Sitorus                   77,43
# 220411100016	Hairyanto Gading Simanjuntak    78,85
# 220411100032	Najwa Puspita                   79,34
# 220411100025	Zaenab Puspita                  79,43
# 220411100080	Tania Ratna Yuniar              79,58
# 220411100007	Yuliana Vanesa Fujiati          79,77
# 220411100049	Belinda Nurdiyanti              80,29
# 220411100040	Leo Putra                       80,30
# 220411100008	Gading Permadi                  80,33
# 220411100098	Ani Maida Aryani                80,64
# 220411100088	Ade Padmi Laksita               80,90
# 220411100036	Hana Yulia Astuti               82,52
# 220411100013	Aris Gamani Hidayat             83,23
# 220411100039	Zelaya Maryati                  83,8
# 220411100030	Dacin Saputra                   84,29
# 220411100061	Nabila Halimah                  84,57
# 220411100033	Garan Mandala                   85,26
# 220411100093	Capa Prabowo                    86,11
# 220411100092	Daru Widodo                     86,59
# 220411100073	Vanya Lintang Anggraini         87,10
# 220411100003	Samiah Novitasari               87,4
# 220411100018	Gawati Laksmiwati               88,12
# 220411100038	Patricia Winarsih               88,49
# 220411100015	Sari Novitasari                 88,50
# 220411100074	Dian Samiah Mardhiyah           88,61
# 220411100084	Nadine Ophelia Utami            88,77
# 220411100009	Erik Megantara                  89,36
# 220411100079	Anastasia Septi Safitri         89,63
# 220411100065	Umi Yulianti                    90,27
# 220411100082	Gasti Yulianti                  90,66
# 220411100100	Dewi Melinda Kuswandari         91,27
# 220411100026	Zaenab Nasyiah                  91,41
# 220411100081	Lukman Makara Nashiruddin       92,72
# 220411100002	Himawan Rajata                  93,33
# 220411100097	Zulfa Elma Padmasari            93,81
# 220411100023	Gilda Ophelia Rahmawati         94,20
# 220411100054	Upik Dongoran                   94,30
# 220411100078	Salman Saefullah                95,40
# 220411100005	Bala Thamrin                    95,59
# 220411100085	Dodo Hakim                      96,68
# 220411100055	Zamira Wahyuni                  96,89
# 220411100058	Parman Martana Prasetyo         97,23
# 220411100045	Edi Praba Manullang             97,28
# 220411100091	Mulyanto Zulkarnain             97,37
# 220411100051	Dacin Erik Nababan              97,4
# 220411100077	Prayoga Hardiansyah             97,82
# 220411100029	Amelia Kamaria Nuraini          98,26
# 220411100006	Kenari Mahfud Suwarno           98,64
# 220411100067	Titi Usamah                     99,0
# 220411100096	Wulan Nasyiah                   99,27
# 220411100089	Lintang Jessica Hariyah         99,28
# 220411100012	Nadia Kezia Susanti             99,41
