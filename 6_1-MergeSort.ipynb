# %%
def merge_sort(a_list):
    print("Splitting ", a_list)
    if len(a_list) > 1:
        mid = len(a_list) // 2
        left_half = a_list[:mid]
        right_half = a_list[mid:]
        merge_sort(left_half)
        merge_sort(right_half)
        i = 0 #indeks left half
        j = 0 #indeks right half
        k = 0 # indeks hasil merging/sorting
        while i < len(left_half) and j < len(right_half):
            if left_half[i] < right_half[j]:
                a_list[k] = left_half[i]
                i += 1
            else:
                a_list[k] = right_half[j]
                j += 1
            k += 1
        while i < len(left_half):
            a_list[k] = left_half[i]
            i += 1
            k += 1
        while j < len(right_half):
            a_list[k] = right_half[j]
            j += 1
            k += 1
    print("Merging ", a_list)

# %%
a = [38,12,65,22,78,25,83,21,90]
merge_sort(a)
# Out:
# Splitting  [38, 12, 65, 22, 78, 25, 83, 21, 90]
# Splitting  [38, 12, 65, 22]
# Splitting  [38, 12]
# Splitting  [38]
# Merging  [38]
# Splitting  [12]
# Merging  [12]
# Merging  [12, 38]
# Splitting  [65, 22]
# Splitting  [65]
# Merging  [65]
# Splitting  [22]
# Merging  [22]
# Merging  [22, 65]
# Merging  [12, 22, 38, 65]
# Splitting  [78, 25, 83, 21, 90]
# Splitting  [78, 25]
# Splitting  [78]
# Merging  [78]
# Splitting  [25]
# Merging  [25]
# Merging  [25, 78]
# Splitting  [83, 21, 90]
# Splitting  [83]
# Merging  [83]
# Splitting  [21, 90]
# Splitting  [21]
# Merging  [21]
# Splitting  [90]
# Merging  [90]
# Merging  [21, 90]
# Merging  [21, 83, 90]
# Merging  [21, 25, 78, 83, 90]
# Merging  [12, 21, 22, 25, 38, 65, 78, 83, 90]

# %%
def mergeSort(listData):
    print('Split',listData)
    if len(listData)>1 :
        mid = len(listData)//2
        leftHalf = listData[:mid]
        rightHalf = listData[mid:]
        mergeSort(leftHalf)
        mergeSort(rightHalf)
        i = 0
        j = 0
        k = 0
        while i < len(leftHalf) and j < len(rightHalf):
            print('Perbandingan',leftHalf[i],'><',rightHalf[j])
            if leftHalf[i] < rightHalf[j]:
                listData[k] = leftHalf[i]
                i+=1
            else:
                listData[k] = rightHalf[j]
                j+=1
            k+=1
        while i<len(leftHalf):
            print('Sisipkan left',leftHalf[i])
            listData[k] = leftHalf[i]
            i+=1
            k+=1
        while j < len(rightHalf):
            print('Sisipkan right',rightHalf[j])
            listData[k] = rightHalf[j]
            j+=1
            k+=1
    print('Merge',listData)
        
c = [60,11,37,0]
mergeSort(a)
# Out:
# Split [12, 21, 22, 25, 38, 65, 78, 83, 90]
# Split [12, 21, 22, 25]
# Split [12, 21]
# Split [12]
# Merge [12]
# Split [21]
# Merge [21]
# Perbandingan 12 >< 21
# Sisipkan right 21
# Merge [12, 21]
# Split [22, 25]
# Split [22]
# Merge [22]
# Split [25]
# Merge [25]
# Perbandingan 22 >< 25
# Sisipkan right 25
# Merge [22, 25]
# Perbandingan 12 >< 22
# Perbandingan 21 >< 22
# Sisipkan right 22
# Sisipkan right 25
# Merge [12, 21, 22, 25]
# Split [38, 65, 78, 83, 90]
# Split [38, 65]
# Split [38]
# Merge [38]
# Split [65]
# Merge [65]
# Perbandingan 38 >< 65
# Sisipkan right 65
# Merge [38, 65]
# Split [78, 83, 90]
# Split [78]
# Merge [78]
# Split [83, 90]
# Split [83]
# Merge [83]
# Split [90]
# Merge [90]
# Perbandingan 83 >< 90
# Sisipkan right 90
# Merge [83, 90]
# Perbandingan 78 >< 83
# Sisipkan right 83
# Sisipkan right 90
# Merge [78, 83, 90]
# Perbandingan 38 >< 78
# Perbandingan 65 >< 78
# Sisipkan right 78
# Sisipkan right 83
# Sisipkan right 90
# ...
